# %% [markdown]
# <a href="https://www.kaggle.com/code/tanavbajaj/basics-of-deep-learning-classification?scriptVersionId=135934265" target="_blank"><img align="left" alt="Kaggle" title="Open in Kaggle" src="https://kaggle.com/static/images/open-in-kaggle.svg"></a>

# %% [markdown]
# # Basics of Deep Learning:Classification
#
# In this notebook I will be showing you a simple model that can be used for classification and also show the importance of model architecture by comparing it with a CNN based algorithm on Cifar-10 Dataset

# %% [markdown]
# # 1 Import Libraries

# %%
import tensorflow as tf 
import numpy as np
import matplotlib.pyplot as plt
from tensorflow.keras.layers import Input, Conv2D, Dense, Flatten, Dropout
from tensorflow.keras.layers import GlobalMaxPooling2D, MaxPooling2D
from tensorflow.keras.layers import BatchNormalization
from tensorflow.keras.models import Model
from keras.models import Sequential
from keras.layers import Conv2D, MaxPooling2D, Flatten, Dense, Dropout, BatchNormalization
from keras.callbacks import EarlyStopping, ReduceLROnPlateau
# Out:
# /opt/conda/lib/python3.10/site-packages/tensorflow_io/python/ops/__init__.py:98: UserWarning: unable to load libtensorflow_io_plugins.so: unable to open file: libtensorflow_io_plugins.so, from paths: ['/opt/conda/lib/python3.10/site-packages/tensorflow_io/python/ops/libtensorflow_io_plugins.so']
# caused by: ['/opt/conda/lib/python3.10/site-packages/tensorflow_io/python/ops/libtensorflow_io_plugins.so: undefined symbol: _ZN3tsl6StatusC1EN10tensorflow5error4CodeESt17basic_string_viewIcSt11char_traitsIcEENS_14SourceLocationE']
#   warnings.warn(f"unable to load libtensorflow_io_plugins.so: {e}")
# /opt/conda/lib/python3.10/site-packages/tensorflow_io/python/ops/__init__.py:104: UserWarning: file system plugins are not loaded: unable to open file: libtensorflow_io.so, from paths: ['/opt/conda/lib/python3.10/site-packages/tensorflow_io/python/ops/libtensorflow_io.so']
# caused by: ['/opt/conda/lib/python3.10/site-packages/tensorflow_io/python/ops/libtensorflow_io.so: undefined symbol: _ZTVN10tensorflow13GcsFileSystemE']
#   warnings.warn(f"file system plugins are not loaded: {e}")

# %% [markdown]
# # 2 Load Dataset

# %%
cifar10 = tf.keras.datasets.cifar10
 
# Distribute it to train and test set
(x_train, y_train), (x_test, y_test) = cifar10.load_data()
print(x_train.shape, y_train.shape, x_test.shape, y_test.shape)
# Out:
# Downloading data from https://www.cs.toronto.edu/~kriz/cifar-10-python.tar.gz
# 170498071/170498071 [==============================] - 3s 0us/step
# (50000, 32, 32, 3) (50000, 1) (10000, 32, 32, 3) (10000, 1)

# %% [markdown]
# # 3 Preprocessing

# %%
# Reduce pixel values
x_train, x_test = x_train / 255.0, x_test / 255.0
 
# flatten the label values
y_train, y_test = y_train.flatten(), y_test.flatten()

# %%
fig, ax = plt.subplots(5, 5)
k = 0
 
for i in range(5):
    for j in range(5):
        ax[i][j].imshow(x_train[k], aspect='auto')
        k += 1
 
plt.show()

# %% [markdown]
# # 4 Basic Model
# # 4.1 Defining the model

# %%
# Define the sequential model
model = tf.keras.Sequential([
    # Flattening the input
    tf.keras.layers.Flatten(input_shape=(32, 32, 3)),  # Input Layer
    
    # Hidden layer with 256 units and ReLU activation
    tf.keras.layers.Dense(256, activation='relu'),  # First Hidden Layer
    
    # Hidden layer with 128 units and ReLU activation
    tf.keras.layers.Dense(128, activation='relu'),  # Second Hidden Layer
    
    # Hidden layer with 64 units and ReLU activation
    tf.keras.layers.Dense(64, activation='relu'),  # Third Hidden Layer
    
    # Output layer with 10 units for class probabilities
    tf.keras.layers.Dense(10, activation='softmax')  # Output Layer
])

# %% [markdown]
# # 4.2 Compile the model

# %%
# Compile the model
model.compile(optimizer='adam',
              loss='sparse_categorical_crossentropy',
              metrics=['accuracy'])

# Print the model summary
model.summary()
# Out:
# Model: "sequential"
# _________________________________________________________________
#  Layer (type)                Output Shape              Param #
# =================================================================
#  flatten (Flatten)           (None, 3072)              0
#
#  dense (Dense)               (None, 256)               786688
#
#  dense_1 (Dense)             (None, 128)               32896
#
#  dense_2 (Dense)             (None, 64)                8256
#
#  dense_3 (Dense)             (None, 10)                650
#
# =================================================================
# Total params: 828,490
# Trainable params: 828,490
# Non-trainable params: 0
# _________________________________________________________________

# %% [markdown]
# # 4.3 Training the model

# %%
# %%time
# Fit the model
history = model.fit(x_train, y_train, validation_data=(x_test, y_test), epochs=25)
# Out:
# Epoch 1/25
# 1563/1563 [==============================] - 11s 4ms/step - loss: 1.8759 - accuracy: 0.3205 - val_loss: 1.7370 - val_accuracy: 0.3794
# Epoch 2/25
# 1563/1563 [==============================] - 6s 4ms/step - loss: 1.6872 - accuracy: 0.3926 - val_loss: 1.6627 - val_accuracy: 0.4037
# Epoch 3/25
# 1563/1563 [==============================] - 6s 4ms/step - loss: 1.6034 - accuracy: 0.4244 - val_loss: 1.6140 - val_accuracy: 0.4122
# Epoch 4/25
# 1563/1563 [==============================] - 6s 4ms/step - loss: 1.5545 - accuracy: 0.4428 - val_loss: 1.6376 - val_accuracy: 0.4215
# Epoch 5/25
# 1563/1563 [==============================] - 7s 4ms/step - loss: 1.5276 - accuracy: 0.4534 - val_loss: 1.5009 - val_accuracy: 0.4693
# Epoch 6/25
# 1563/1563 [==============================] - 6s 4ms/step - loss: 1.4959 - accuracy: 0.4630 - val_loss: 1.5508 - val_accuracy: 0.4440
# Epoch 7/25
# 1563/1563 [==============================] - 6s 4ms/step - loss: 1.4729 - accuracy: 0.4708 - val_loss: 1.5094 - val_accuracy: 0.4583
# Epoch 8/25
# 1563/1563 [==============================] - 5s 3ms/step - loss: 1.4577 - accuracy: 0.4807 - val_loss: 1.4729 - val_accuracy: 0.4723
# Epoch 9/25
# 1563/1563 [==============================] - 6s 4ms/step - loss: 1.4349 - accuracy: 0.4861 - val_loss: 1.5109 - val_accuracy: 0.4647
# Epoch 10/25
# 1563/1563 [==============================] - 6s 4ms/step - loss: 1.4173 - accuracy: 0.4957 - val_loss: 1.4675 - val_accuracy: 0.4761
# Epoch 11/25
# 1563/1563 [==============================] - 6s 4ms/step - loss: 1.4026 - accuracy: 0.4969 - val_loss: 1.4596 - val_accuracy: 0.4840
# Epoch 12/25
# 1563/1563 [==============================] - 6s 4ms/step - loss: 1.3899 - accuracy: 0.5005 - val_loss: 1.4601 - val_accuracy: 0.4859
# Epoch 13/25
# 1563/1563 [==============================] - 6s 4ms/step - loss: 1.3756 - accuracy: 0.5071 - val_loss: 1.4671 - val_accuracy: 0.4834
# Epoch 14/25
# 1563/1563 [==============================] - 6s 4ms/step - loss: 1.3633 - accuracy: 0.5132 - val_loss: 1.4873 - val_accuracy: 0.4792
# Epoch 15/25
# 1563/1563 [==============================] - 6s 4ms/step - loss: 1.3510 - accuracy: 0.5164 - val_loss: 1.4352 - val_accuracy: 0.4919
# Epoch 16/25
# 1563/1563 [==============================] - 6s 4ms/step - loss: 1.3396 - accuracy: 0.5213 - val_loss: 1.4588 - val_accuracy: 0.4901
# Epoch 17/25
# 1563/1563 [==============================] - 5s 3ms/step - loss: 1.3312 - accuracy: 0.5246 - val_loss: 1.4681 - val_accuracy: 0.4876
# Epoch 18/25
# 1563/1563 [==============================] - 6s 4ms/step - loss: 1.3217 - accuracy: 0.5262 - val_loss: 1.4602 - val_accuracy: 0.4897
# Epoch 19/25
# 1563/1563 [==============================] - 6s 4ms/step - loss: 1.3108 - accuracy: 0.5319 - val_loss: 1.4703 - val_accuracy: 0.4792
# Epoch 20/25
# 1563/1563 [==============================] - 6s 4ms/step - loss: 1.3023 - accuracy: 0.5343 - val_loss: 1.4282 - val_accuracy: 0.4980
# Epoch 21/25
# 1563/1563 [==============================] - 6s 4ms/step - loss: 1.2981 - accuracy: 0.5348 - val_loss: 1.5044 - val_accuracy: 0.4746
# Epoch 22/25
# 1563/1563 [==============================] - 6s 4ms/step - loss: 1.2910 - accuracy: 0.5401 - val_loss: 1.4877 - val_accuracy: 0.4805
# Epoch 23/25
# 1563/1563 [==============================] - 6s 4ms/step - loss: 1.2795 - accuracy: 0.5413 - val_loss: 1.4344 - val_accuracy: 0.4910
# Epoch 24/25
# 1563/1563 [==============================] - 6s 4ms/step - loss: 1.2701 - accuracy: 0.5448 - val_loss: 1.4455 - val_accuracy: 0.4888
# Epoch 25/25
# 1563/1563 [==============================] - 6s 4ms/step - loss: 1.2618 - accuracy: 0.5470 - val_loss: 1.4492 - val_accuracy: 0.4939
# CPU times: user 2min 47s, sys: 14.9 s, total: 3min 2s
# Wall time: 2min 30s

# %% [markdown]
# # 4.4 Evaluate the model

# %%
# Plot accuracy per iteration
plt.plot(history.history['accuracy'], label='acc', color='red')
plt.plot(history.history['val_accuracy'], label='val_acc', color='green')
plt.legend()

# %%
# Evaluate the model on test data
test_loss, test_accuracy = model.evaluate(x_test, y_test)
print(f'Test loss: {test_loss}')
print(f'Test accuracy: {test_accuracy}')
# Out:
# 313/313 [==============================] - 1s 2ms/step - loss: 1.4492 - accuracy: 0.4939
# Test loss: 1.449213981628418
# Test accuracy: 0.49390000104904175

# %% [markdown]
# # 5 CNN Based Architecture
# # 5.1 Defining the Model

# %%
# Define the number of classes
K = len(set(y_train))
print("Number of classes:", K)

# Build the model
model = Sequential()

# Convolutional layers
model.add(Conv2D(32, (3, 3), activation='relu', padding='same', input_shape=x_train.shape[1:]))
model.add(BatchNormalization())
model.add(Conv2D(32, (3, 3), activation='relu', padding='same'))
model.add(BatchNormalization())
model.add(MaxPooling2D((2, 2)))

model.add(Conv2D(64, (3, 3), activation='relu', padding='same'))
model.add(BatchNormalization())
model.add(Conv2D(64, (3, 3), activation='relu', padding='same'))
model.add(BatchNormalization())
model.add(MaxPooling2D((2, 2)))

model.add(Conv2D(128, (3, 3), activation='relu', padding='same'))
model.add(BatchNormalization())
model.add(Conv2D(128, (3, 3), activation='relu', padding='same'))
model.add(BatchNormalization())
model.add(MaxPooling2D((2, 2)))

model.add(Flatten())
model.add(Dropout(0.2))

# Hidden layers
model.add(Dense(1024, activation='relu'))
model.add(Dropout(0.2))

# Output layer
model.add(Dense(K, activation='softmax'))

# Model summary
model.summary()
# Out:
# Number of classes: 10
# Model: "sequential_1"
# _________________________________________________________________
#  Layer (type)                Output Shape              Param #
# =================================================================
#  conv2d (Conv2D)             (None, 32, 32, 32)        896
#
#  batch_normalization (BatchN  (None, 32, 32, 32)       128
#  ormalization)
#
#  conv2d_1 (Conv2D)           (None, 32, 32, 32)        9248
#
#  batch_normalization_1 (Batc  (None, 32, 32, 32)       128
#  hNormalization)
#
#  max_pooling2d (MaxPooling2D  (None, 16, 16, 32)       0
#  )
#
#  conv2d_2 (Conv2D)           (None, 16, 16, 64)        18496
#
#  batch_normalization_2 (Batc  (None, 16, 16, 64)       256
#  hNormalization)
#
#  conv2d_3 (Conv2D)           (None, 16, 16, 64)        36928
#
#  batch_normalization_3 (Batc  (None, 16, 16, 64)       256
#  hNormalization)
#
#  max_pooling2d_1 (MaxPooling  (None, 8, 8, 64)         0
#  2D)
#
#  conv2d_4 (Conv2D)           (None, 8, 8, 128)         73856
#
#  batch_normalization_4 (Batc  (None, 8, 8, 128)        512
#  hNormalization)
#
#  conv2d_5 (Conv2D)           (None, 8, 8, 128)         147584
#
#  batch_normalization_5 (Batc  (None, 8, 8, 128)        512
#  hNormalization)
#
#  max_pooling2d_2 (MaxPooling  (None, 4, 4, 128)        0
#  2D)
#
#  flatten_1 (Flatten)         (None, 2048)              0
#
#  dropout (Dropout)           (None, 2048)              0
#
#  dense_4 (Dense)             (None, 1024)              2098176
#
#  dropout_1 (Dropout)         (None, 1024)              0
#
#  dense_5 (Dense)             (None, 10)                10250
#
# =================================================================
# Total params: 2,397,226
# Trainable params: 2,396,330
# Non-trainable params: 896
# _________________________________________________________________

# %% [markdown]
# # 5.2 Compile the model

# %%
# Compile
model.compile(optimizer='adam',
              loss='sparse_categorical_crossentropy',
              metrics=['accuracy'])

# %% [markdown]
# # 5.3 Define Callbacks

# %%
# Define the callbacks
early_stopping = EarlyStopping(monitor='val_loss', patience=5, restore_best_weights=True)
reduce_lr = ReduceLROnPlateau(monitor='val_loss', factor=0.1, patience=5, min_lr=0.00001)

# %% [markdown]
# # 5.4 Train the model

# %%
# %%time
# Fit
r = model.fit(
  x_train, y_train, validation_data=(x_test, y_test), epochs=50,
  callbacks=[early_stopping, reduce_lr])
# Out:
# Epoch 1/50
# 1563/1563 [==============================] - 21s 8ms/step - loss: 1.3186 - accuracy: 0.5422 - val_loss: 1.0700 - val_accuracy: 0.6231 - lr: 0.0010
# Epoch 2/50
# 1563/1563 [==============================] - 11s 7ms/step - loss: 0.8512 - accuracy: 0.7044 - val_loss: 0.7749 - val_accuracy: 0.7359 - lr: 0.0010
# Epoch 3/50
# 1563/1563 [==============================] - 11s 7ms/step - loss: 0.6928 - accuracy: 0.7614 - val_loss: 0.7623 - val_accuracy: 0.7473 - lr: 0.0010
# Epoch 4/50
# 1563/1563 [==============================] - 11s 7ms/step - loss: 0.5826 - accuracy: 0.7991 - val_loss: 0.8036 - val_accuracy: 0.7399 - lr: 0.0010
# Epoch 5/50
# 1563/1563 [==============================] - 12s 8ms/step - loss: 0.4956 - accuracy: 0.8296 - val_loss: 0.6465 - val_accuracy: 0.7918 - lr: 0.0010
# Epoch 6/50
# 1563/1563 [==============================] - 11s 7ms/step - loss: 0.4234 - accuracy: 0.8519 - val_loss: 0.6874 - val_accuracy: 0.7802 - lr: 0.0010
# Epoch 7/50
# 1563/1563 [==============================] - 11s 7ms/step - loss: 0.3567 - accuracy: 0.8764 - val_loss: 0.5929 - val_accuracy: 0.8154 - lr: 0.0010
# Epoch 8/50
# 1563/1563 [==============================] - 12s 8ms/step - loss: 0.3001 - accuracy: 0.8958 - val_loss: 0.6686 - val_accuracy: 0.8055 - lr: 0.0010
# Epoch 9/50
# 1563/1563 [==============================] - 11s 7ms/step - loss: 0.2649 - accuracy: 0.9089 - val_loss: 0.6139 - val_accuracy: 0.8147 - lr: 0.0010
# Epoch 10/50
# 1563/1563 [==============================] - 11s 7ms/step - loss: 0.2218 - accuracy: 0.9233 - val_loss: 0.6269 - val_accuracy: 0.8237 - lr: 0.0010
# Epoch 11/50
# 1563/1563 [==============================] - 11s 7ms/step - loss: 0.1951 - accuracy: 0.9330 - val_loss: 0.7553 - val_accuracy: 0.8086 - lr: 0.0010
# Epoch 12/50
# 1563/1563 [==============================] - 11s 7ms/step - loss: 0.1777 - accuracy: 0.9389 - val_loss: 0.6972 - val_accuracy: 0.8147 - lr: 0.0010
# CPU times: user 2min 31s, sys: 8.78 s, total: 2min 40s
# Wall time: 2min 26s

# %% [markdown]
# # 5.5 Evaluating the model

# %%
# Plot accuracy per iteration
plt.plot(r.history['accuracy'], label='acc', color='red')
plt.plot(r.history['val_accuracy'], label='val_acc', color='green')
plt.legend()

# %%
# Evaluate the model on test data
test_loss, test_accuracy = model.evaluate(x_test, y_test)
print(f'Test loss: {test_loss}')
print(f'Test accuracy: {test_accuracy}')
# Out:
# 313/313 [==============================] - 1s 3ms/step - loss: 0.5929 - accuracy: 0.8154
# Test loss: 0.5928546190261841
# Test accuracy: 0.8154000043869019

# %% [markdown]
# # 5.6 Checking the final model with the some examples

# %%
# label mapping
 
labels = '''airplane automobile bird cat deer dog frog horseship truck'''.split()
 
# select the image from our test dataset
image_number = 290
 
# display the image
plt.imshow(x_test[image_number])
 
# load the image in an array
n = np.array(x_test[image_number])
 
# reshape it
p = n.reshape(1, 32, 32, 3)
 
# pass in the network for prediction and
# save the predicted label
predicted_label = labels[model.predict(p).argmax()]
 
# load the original label
original_label = labels[y_test[image_number]]
 
# display the result
print("Original label is {} and predicted label is {}".format(
    original_label, predicted_label))
# Out:
# 1/1 [==============================] - 0s 259ms/step
# Original label is automobile and predicted label is automobile

# %% [markdown]
# # Thank You for Reading
